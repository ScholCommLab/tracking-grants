# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from habanero import Crossref
from ratelimit import limits, sleep_and_retry
from tracking_grants import articles_f, cr_metadata_f, email, tool_name
from tracking_grants.utils.logging import logger
import json

# %%
from tqdm.auto import tqdm

# %%
# load articles
articles = pd.read_csv(articles_f)

# %%
cr = Crossref(mailto=email, ua_string=tool_name)

# %%
@sleep_and_retry
@limits(calls=10, period=1)
def query_crossref(cr, dois):
    return cr.works(dois)

# %%
dois = articles.DOI.tolist()

# %%
dois_per_call = 10
r = list(range(0, len(dois), dois_per_call))
r = r + [len(dois)]

results = []
for ix in tqdm(range(len(r)-1), total=len(r)-1):
    response = query_crossref(cr, dois[r[ix]:r[ix+1]])
    results.extend(response)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))

# %%
with open(cr_metadata_f, 'w') as f:
    json.dump(results, f)

# %% [markdown]
# ## Processing data

# %%
results = json.loads(open(cr_metadata_f, "r").read())

# %%
direct_fields = ["ISSN", 'container-title', 'publisher', 'is-referenced-by-count', 'references-count', 'subject']
transform_fields = ["authors_count", ]
date_fields = ['created', 'deposited', 'indexed', 'published-online', 'issued']

# %%
df = pd.DataFrame(index=articles.DOI.tolist(), columns=direct_fields + transform_fields + date_fields)

# %%
df.head()
# Out:
#                                                     ISSN  \
# 10.2144/04365st01                 [0736-6205, 1940-9818]
# 10.1002/jcb.10712                 [0730-2312, 1097-4644]
# 10.1081/cnv-120025093                          0735-7907
# 10.1097/00129492-200409000-00027                     NaN
# 10.1097/00129492-200307000-00022                     NaN
#
#                                                      container-title  \
# 10.2144/04365st01                                    [BioTechniques]
# 10.1002/jcb.10712                 [Journal of Cellular Biochemistry]
# 10.1081/cnv-120025093                           Cancer Investigation
# 10.1097/00129492-200409000-00027                                 NaN
# 10.1097/00129492-200307000-00022                                 NaN
#
#                                            publisher is-referenced-by-count  \
# 10.2144/04365st01                 Future Science Ltd                     42
# 10.1002/jcb.10712                              Wiley                     11
# 10.1081/cnv-120025093             Informa UK Limited                     12
# 10.1097/00129492-200409000-00027                 NaN                    NaN
# 10.1097/00129492-200307000-00022                 NaN                    NaN
#
#                                  references-count  \
# 10.2144/04365st01                              12
# 10.1002/jcb.10712                              25
# 10.1081/cnv-120025093                         157
# 10.1097/00129492-200409000-00027              NaN
# 10.1097/00129492-200307000-00022              NaN
#
#                                                                           subject  \
# 10.2144/04365st01                                                             NaN
# 10.1002/jcb.10712                 [Cell Biology, Biochemistry, Molecular Biology]
# 10.1081/cnv-120025093                                                         NaN
# 10.1097/00129492-200409000-00027                                              NaN
# 10.1097/00129492-200307000-00022                                              NaN
#
#                                  authors_count created deposited indexed  \
# 10.2144/04365st01                            6    2018      2019    2020
# 10.1002/jcb.10712                            7    2003      2018    2020
# 10.1081/cnv-120025093                      NaN     NaN       NaN     NaN
# 10.1097/00129492-200409000-00027           NaN     NaN       NaN     NaN
# 10.1097/00129492-200307000-00022           NaN     NaN       NaN     NaN
#
#                                  published-online issued
# 10.2144/04365st01                             NaN   2004
# 10.1002/jcb.10712                            2003   2003
# 10.1081/cnv-120025093                         NaN    NaN
# 10.1097/00129492-200409000-00027              NaN    NaN
# 10.1097/00129492-200307000-00022              NaN    NaN

# %%
for r in tqdm(results, total=len(results)):
    json = r['message']
    doi = json['DOI']
    
    for direct_f in direct_fields:
        if direct_f in json:
            df.loc[doi, direct_f] = str(json[direct_f])
    
    # authors
    if 'author' in json:
        df.loc[doi, 'authors_count'] = len(json['author'])
    
    for date_f in date_fields:
        if date_f in json:
            try:
                df.loc[doi, date_f] = json[date_f]['date-parts'][0][0]
            except:
                print(date_f, json[date_f])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8595.0), HTML(value='')))

# %%
df = df.drop_duplicates()

# %%
df = df.replace(0, np.nan)
df = df.rename(columns={
    'container-title': 'journal_name',
    'is-referenced-by-count':'coci_citations',
    'references-count': 'references',
    'subject': 'cr_subject',
})

# %%
len(articles)
# Out:
# 8595

# %%
# Out:
#       reference_id  grant_id program     score  \
# 0                0  NF000002    NFRP  0.442644
# 1                2  NF000010    NFRP  0.433704
# 2                3  NF000014    NFRP  0.498568
# 3                4  NF000015    NFRP  0.937954
# 4                5  NF000015    NFRP  0.531327
# ...            ...       ...     ...       ...
# 8590          9520  OR150169   PRORP  0.932630
# 8591          9521  OR150169   PRORP  0.940352
# 8592          9522  OR160120   PRORP  0.790298
# 8593          9523  OR160120   PRORP  0.939744
# 8594          9524  OR160120   PRORP  0.800683
#
#                                    DOI                              pmid
# 0                    10.2144/04365st01                 10.2144/04365ST01
# 1                    10.1002/jcb.10712                 10.1002/JCB.10712
# 2                10.1081/cnv-120025093             10.1081/CNV-120025093
# 3     10.1097/00129492-200409000-00027  10.1097/00129492-200409000-00027
# 4     10.1097/00129492-200307000-00022  10.1097/00129492-200307000-00022
# ...                                ...                               ...
# 8590           10.1089/wound.2017.0737           10.1089/WOUND.2017.0737
# 8591           10.1089/wound.2016.0719           10.1089/WOUND.2016.0719
# 8592                 10.1115/1.4039342                 10.1115/1.4039342
# 8593        10.1109/tnsre.2018.2848845        10.1109/TNSRE.2018.2848845
# 8594                 10.1115/1.4040779                 10.1115/1.4040779
#
# [8595 rows x 6 columns]

# %%
articles.merge(df, left_on="DOI", right_index=True)
# Out:
#       reference_id  grant_id program     score  \
# 0                0  NF000002    NFRP  0.442644
# 1                2  NF000010    NFRP  0.433704
# 2                3  NF000014    NFRP  0.498568
# 592            616  NF990031    NFRP  0.855856
# 3                4  NF000015    NFRP  0.937954
# ...            ...       ...     ...       ...
# 8590          9520  OR150169   PRORP  0.932630
# 8591          9521  OR150169   PRORP  0.940352
# 8592          9522  OR160120   PRORP  0.790298
# 8593          9523  OR160120   PRORP  0.939744
# 8594          9524  OR160120   PRORP  0.800683
#
#                                    DOI                        ISSN  \
# 0                    10.2144/04365st01  ['0736-6205', '1940-9818']
# 1                    10.1002/jcb.10712  ['0730-2312', '1097-4644']
# 2                10.1081/cnv-120025093  ['0735-7907', '1532-4192']
# 592              10.1081/cnv-120025093  ['0735-7907', '1532-4192']
# 3     10.1097/00129492-200409000-00027               ['1531-7129']
# ...                                ...                         ...
# 8590           10.1089/wound.2017.0737  ['2162-1918', '2162-1934']
# 8591           10.1089/wound.2016.0719  ['2162-1918', '2162-1934']
# 8592                 10.1115/1.4039342  ['1942-4302', '1942-4310']
# 8593        10.1109/tnsre.2018.2848845  ['1534-4320', '1558-0210']
# 8594                 10.1115/1.4040779  ['1050-0472', '1528-9001']
#
#                                            journal_name  \
# 0                                     ['BioTechniques']
# 1                  ['Journal of Cellular Biochemistry']
# 2                              ['Cancer Investigation']
# 592                            ['Cancer Investigation']
# 3                             ['Otology & Neurotology']
# ...                                                 ...
# 8590                         ['Advances in Wound Care']
# 8591                         ['Advances in Wound Care']
# 8592             ['Journal of Mechanisms and Robotics']
# 8593  ['IEEE Transactions on Neural Systems and Reha...
# 8594                   ['Journal of Mechanical Design']
#
#                                               publisher coci_citations  \
# 0                                    Future Science Ltd             42
# 1                                                 Wiley             11
# 2                                    Informa UK Limited             12
# 592                                  Informa UK Limited             12
# 3             Ovid Technologies (Wolters Kluwer Health)             56
# ...                                                 ...            ...
# 8590                               Mary Ann Liebert Inc              2
# 8591                               Mary Ann Liebert Inc              7
# 8592                                 ASME International              0
# 8593  Institute of Electrical and Electronics Engine...              1
# 8594                                 ASME International              0
#
#      references                                         cr_subject  \
# 0            12                                                NaN
# 1            25  ['Cell Biology', 'Biochemistry', 'Molecular Bi...
# 2           157  ['Cancer Research', 'Oncology', 'General Medic...
# 592         157  ['Cancer Research', 'Oncology', 'General Medic...
# 3            28  ['Sensory Systems', 'Otorhinolaryngology', 'Cl...
# ...         ...                                                ...
# 8590         21                                                NaN
# 8591         14                                                NaN
# 8592         11                                                NaN
# 8593          0                                                NaN
# 8594         36  ['Mechanical Engineering', 'Mechanics of Mater...
#
#      authors_count created deposited indexed published-online issued
# 0                6    2018      2019    2020              NaN   2004
# 1                7    2003      2018    2020             2003   2003
# 2                1    2003      2020    2020             2003   2003
# 592              1    2003      2020    2020             2003   2003
# 3                4    2004      2018    2020              NaN   2004
# ...            ...     ...       ...     ...              ...    ...
# 8590            12    2017      2018    2020              NaN   2017
# 8591             6    2017      2018    2020              NaN   2017
# 8592             5    2018      2019    2020             2018   2018
# 8593             2    2018      2018    2020              NaN   2018
# 8594             4    2018      2019    2020             2018   2018
#
# [8577 rows x 17 columns]
