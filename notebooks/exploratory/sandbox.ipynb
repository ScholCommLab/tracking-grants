# %%
import pandas as pd
from pathlib import Path
import json

import requests
from tqdm.notebook import tqdm

from ratelimit import limits, sleep_and_retry

# %%
from tracking_grants import articles_f, altmetric_f, wos_f, metrics_f

# %%
articles = pd.read_csv(articles_f)

# %%
articles
# Out:
#       reference_id  grant_id program     score  \
# 0                0  TS020006   TSCRP  0.778081
# 1              212  TS020006    NFRP  0.778081
# 2                1  TS020006   TSCRP  0.850938
# 3              211  TS020006    NFRP  0.850938
# 4                2  TS020006   TSCRP  0.823528
# ...            ...       ...     ...       ...
# 8147          9073  OR150169   PRORP  0.940309
# 8148          9074  OR150169   PRORP  0.932610
# 8149          9075  OR160120   PRORP  0.790023
# 8150          9076  OR160120   PRORP  0.939601
# 8151          9077  OR160120   PRORP  0.800471
#
#                                      DOI        pmid  \
# 0              10.1016/j.nbd.2007.07.015  17714952.0
# 1              10.1016/j.nbd.2007.07.015  17714952.0
# 2     10.1212/01.wnl.0000158653.81008.49  15851742.0
# 3     10.1212/01.wnl.0000158653.81008.49  15851742.0
# 4        10.1128/mcb.25.8.3151-3162.2005  15798201.0
# ...                                  ...         ...
# ...
